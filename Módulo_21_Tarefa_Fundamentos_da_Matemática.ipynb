# %% [markdown]
# <a href="https://colab.research.google.com/github/Mat9408/Atividades_CursoAnalistaDeDados_EBAC/blob/main/M%C3%B3dulo_21_Tarefa_Fundamentos_da_Matem%C3%A1tica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ####Tarefa 1.1
#
# - O algoritmo imprime um dicionário com o número de acidentes registrados por dia. Conforme o contador chega na 27ª meia hora, a contagem é zerada e reiniciada no dia seguinte.

# %% [markdown]
# Tarafa 1.2 Numpy

# %%
# -- read

data = None

with open(file='traffic.csv', mode= 'r', encoding= 'utf8') as fp:

  fp.readline()
  data = fp.read()

# -- analytics
day = 14
incidents = 0
incident_by_day = dict()


for timebox in data.split(sep='\n'):
  timebox_data = timebox.split(sep=';')
# --
# -- inicio da computação escalar
# --

  incidents += np.sum(np.array(timebox_data[1: len(timebox_data) -1], dtype= 'int64'))
  #incident_array= np.array(timebox_data[1:len(timebox_data)-1], dtype= int)
  #incidents_array= incidents_array + (incident_array +1)

  #for incident in timebox_data[1: len(timebox_data)-1]:
   # incidents = incidents + int(incident)
# --
# -- fim da computação escalar
# --
  try:
    half_hour = int(timebox_data[0])

    if half_hour == 27:
      incident_by_day[day] = incidents
      day = day + 1
      incidents = 0
  except ValueError:
    continue

# -- results
for day in incident_by_day:
  print(f'{day}: {incident_by_day[day]}')
# Out:
# 14: 16
# 15: 63
# 16: 94
# 17: 82
# 18: 85
